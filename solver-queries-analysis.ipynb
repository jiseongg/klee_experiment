# %%
from util import *

import os
import pandas as pd

# %%
results = ["%s-%s-7200s" % (pgm, search)
           for pgm in ['bc', 'datamash', 'm4', 'magick-jpg', 'magick-png',
                       'make', 'oggenc', 'sqlite3', 'tcpdump']
           for search in ['dfs', 'nurs:depth', 'random-path']]

# %%
result_dir = 'klee-results'
query_log_file = 'solver-queries.kquery'

result_statistics = dict()

for result in results:
    
    filepath = result_dir + '/' + result + '/' + query_log_file
    parse_result = solver_data_parser(filepath)
    
    if parse_result is None:
        continue
    
    (success, validityResults, initialValuesResults, valueResults,
     truthResults, elapsed_times, query_types) = parse_result
    statistics = pd.DataFrame(
        zip(success, validityResults, initialValuesResults, valueResults,
     truthResults, elapsed_times, query_types),
        columns=["success", "validityResults", "initialValuesResults",
                 "valueResults", "truthResults", "elapsed_times", "query_types"])
    result_statistics[result] = statistics

# %%
summarize_data(result_statistics['bc-dfs-7200s'])
# Out:
# total queries:  7560
# failed queries:  0
# succeeded queries:  7560
# Type: Validity  0
# |-- Validity: -1  0
# |-- Validity: 0  0
# |-- Validity: 1  0
# ==========================
# Type: InitialValues  7560
# |-- Solvable: false  7308
# |-- Solvable: true  252
# ==========================
# Type: Truth:  0
# |-- Is Valid - false 0
# |-- Is Valid - true 0
# ==========================
# Type: Value:  0

# %%
summarize_data(result_statistics['bc-nurs:depth-7200s'])
# Out:
# total queries:  1855
# failed queries:  0
# succeeded queries:  1855
# Type: Validity  0
# |-- Validity: -1  0
# |-- Validity: 0  0
# |-- Validity: 1  0
# ==========================
# Type: InitialValues  1855
# |-- Solvable: false  1621
# |-- Solvable: true  234
# ==========================
# Type: Truth:  0
# |-- Is Valid - false 0
# |-- Is Valid - true 0
# ==========================
# Type: Value:  0

# %%
summarize_data(result_statistics['bc-random-path-7200s'])
# Out:
# total queries:  3508
# failed queries:  0
# succeeded queries:  3508
# Type: Validity  0
# |-- Validity: -1  0
# |-- Validity: 0  0
# |-- Validity: 1  0
# ==========================
# Type: InitialValues  3508
# |-- Solvable: false  3215
# |-- Solvable: true  293
# ==========================
# Type: Truth:  0
# |-- Is Valid - false 0
# |-- Is Valid - true 0
# ==========================
# Type: Value:  0

# %%
summarize_data(result_statistics['datamash-dfs-7200s'])
# Out:
# total queries:  601
# failed queries:  0
# succeeded queries:  601
# Type: Validity  0
# |-- Validity: -1  0
# |-- Validity: 0  0
# |-- Validity: 1  0
# ==========================
# Type: InitialValues  601
# |-- Solvable: false  524
# |-- Solvable: true  77
# ==========================
# Type: Truth:  0
# |-- Is Valid - false 0
# |-- Is Valid - true 0
# ==========================
# Type: Value:  0

# %%
summarize_data(result_statistics['datamash-nurs:depth-7200s'])
# Out:
# total queries:  25
# failed queries:  0
# succeeded queries:  25
# Type: Validity  0
# |-- Validity: -1  0
# |-- Validity: 0  0
# |-- Validity: 1  0
# ==========================
# Type: InitialValues  25
# |-- Solvable: false  0
# |-- Solvable: true  25
# ==========================
# Type: Truth:  0
# |-- Is Valid - false 0
# |-- Is Valid - true 0
# ==========================
# Type: Value:  0

# %%
summarize_data(result_statistics['datamash-random-path-7200s'])
# Out:
# total queries:  25
# failed queries:  0
# succeeded queries:  25
# Type: Validity  0
# |-- Validity: -1  0
# |-- Validity: 0  0
# |-- Validity: 1  0
# ==========================
# Type: InitialValues  25
# |-- Solvable: false  0
# |-- Solvable: true  25
# ==========================
# Type: Truth:  0
# |-- Is Valid - false 0
# |-- Is Valid - true 0
# ==========================
# Type: Value:  0

# %%
summarize_data(result_statistics['m4-dfs-7200s'])
# Out:
# total queries:  1329
# failed queries:  0
# succeeded queries:  1329
# Type: Validity  0
# |-- Validity: -1  0
# |-- Validity: 0  0
# |-- Validity: 1  0
# ==========================
# Type: InitialValues  1329
# |-- Solvable: false  748
# |-- Solvable: true  581
# ==========================
# Type: Truth:  0
# |-- Is Valid - false 0
# |-- Is Valid - true 0
# ==========================
# Type: Value:  0

# %%
summarize_data(result_statistics['m4-nurs:depth-7200s'])
# Out:
# total queries:  1638
# failed queries:  0
# succeeded queries:  1638
# Type: Validity  0
# |-- Validity: -1  0
# |-- Validity: 0  0
# |-- Validity: 1  0
# ==========================
# Type: InitialValues  1638
# |-- Solvable: false  1361
# |-- Solvable: true  277
# ==========================
# Type: Truth:  0
# |-- Is Valid - false 0
# |-- Is Valid - true 0
# ==========================
# Type: Value:  0

# %%
summarize_data(result_statistics['m4-random-path-7200s'])
# Out:
# total queries:  547
# failed queries:  0
# succeeded queries:  547
# Type: Validity  0
# |-- Validity: -1  0
# |-- Validity: 0  0
# |-- Validity: 1  0
# ==========================
# Type: InitialValues  547
# |-- Solvable: false  433
# |-- Solvable: true  114
# ==========================
# Type: Truth:  0
# |-- Is Valid - false 0
# |-- Is Valid - true 0
# ==========================
# Type: Value:  0

# %%
summarize_data(result_statistics['magick-jpg-dfs-7200s'])
# Out:
# total queries:  18
# failed queries:  0
# succeeded queries:  18
# Type: Validity  0
# |-- Validity: -1  0
# |-- Validity: 0  0
# |-- Validity: 1  0
# ==========================
# Type: InitialValues  18
# |-- Solvable: false  0
# |-- Solvable: true  18
# ==========================
# Type: Truth:  0
# |-- Is Valid - false 0
# |-- Is Valid - true 0
# ==========================
# Type: Value:  0

# %%
summarize_data(result_statistics['magick-jpg-nurs:depth-7200s'])
# Out:
# total queries:  18
# failed queries:  0
# succeeded queries:  18
# Type: Validity  0
# |-- Validity: -1  0
# |-- Validity: 0  0
# |-- Validity: 1  0
# ==========================
# Type: InitialValues  18
# |-- Solvable: false  0
# |-- Solvable: true  18
# ==========================
# Type: Truth:  0
# |-- Is Valid - false 0
# |-- Is Valid - true 0
# ==========================
# Type: Value:  0

# %%
summarize_data(result_statistics['magick-jpg-random-path-7200s'])
# Out:
# total queries:  18
# failed queries:  0
# succeeded queries:  18
# Type: Validity  0
# |-- Validity: -1  0
# |-- Validity: 0  0
# |-- Validity: 1  0
# ==========================
# Type: InitialValues  18
# |-- Solvable: false  0
# |-- Solvable: true  18
# ==========================
# Type: Truth:  0
# |-- Is Valid - false 0
# |-- Is Valid - true 0
# ==========================
# Type: Value:  0

# %%
summarize_data(result_statistics['magick-png-dfs-7200s'])
# Out:
# total queries:  18
# failed queries:  0
# succeeded queries:  18
# Type: Validity  0
# |-- Validity: -1  0
# |-- Validity: 0  0
# |-- Validity: 1  0
# ==========================
# Type: InitialValues  18
# |-- Solvable: false  0
# |-- Solvable: true  18
# ==========================
# Type: Truth:  0
# |-- Is Valid - false 0
# |-- Is Valid - true 0
# ==========================
# Type: Value:  0

# %%
summarize_data(result_statistics['magick-png-nurs:depth-7200s'])
# Out:
# total queries:  18
# failed queries:  0
# succeeded queries:  18
# Type: Validity  0
# |-- Validity: -1  0
# |-- Validity: 0  0
# |-- Validity: 1  0
# ==========================
# Type: InitialValues  18
# |-- Solvable: false  0
# |-- Solvable: true  18
# ==========================
# Type: Truth:  0
# |-- Is Valid - false 0
# |-- Is Valid - true 0
# ==========================
# Type: Value:  0

# %%
summarize_data(result_statistics['magick-png-random-path-7200s'])
# Out:
# total queries:  18
# failed queries:  0
# succeeded queries:  18
# Type: Validity  0
# |-- Validity: -1  0
# |-- Validity: 0  0
# |-- Validity: 1  0
# ==========================
# Type: InitialValues  18
# |-- Solvable: false  0
# |-- Solvable: true  18
# ==========================
# Type: Truth:  0
# |-- Is Valid - false 0
# |-- Is Valid - true 0
# ==========================
# Type: Value:  0

# %%
summarize_data(result_statistics['make-dfs-7200s'])
# Out:
# total queries:  169
# failed queries:  3
# succeeded queries:  166
# Type: Validity  0
# |-- Validity: -1  0
# |-- Validity: 0  0
# |-- Validity: 1  0
# ==========================
# Type: InitialValues  169
# |-- Solvable: false  123
# |-- Solvable: true  43
# ==========================
# Type: Truth:  0
# |-- Is Valid - false 0
# |-- Is Valid - true 0
# ==========================
# Type: Value:  0

# %%
summarize_data(result_statistics['make-nurs:depth-7200s'])
# Out:
# total queries:  101
# failed queries:  0
# succeeded queries:  101
# Type: Validity  0
# |-- Validity: -1  0
# |-- Validity: 0  0
# |-- Validity: 1  0
# ==========================
# Type: InitialValues  101
# |-- Solvable: false  63
# |-- Solvable: true  38
# ==========================
# Type: Truth:  0
# |-- Is Valid - false 0
# |-- Is Valid - true 0
# ==========================
# Type: Value:  0

# %%
summarize_data(result_statistics['make-random-path-7200s'])
# Out:
# total queries:  23
# failed queries:  0
# succeeded queries:  23
# Type: Validity  0
# |-- Validity: -1  0
# |-- Validity: 0  0
# |-- Validity: 1  0
# ==========================
# Type: InitialValues  23
# |-- Solvable: false  0
# |-- Solvable: true  23
# ==========================
# Type: Truth:  0
# |-- Is Valid - false 0
# |-- Is Valid - true 0
# ==========================
# Type: Value:  0

# %%
summarize_data(result_statistics['oggenc-dfs-7200s'])
# Out:
# total queries:  2827
# failed queries:  0
# succeeded queries:  2827
# Type: Validity  0
# |-- Validity: -1  0
# |-- Validity: 0  0
# |-- Validity: 1  0
# ==========================
# Type: InitialValues  2827
# |-- Solvable: false  2181
# |-- Solvable: true  646
# ==========================
# Type: Truth:  0
# |-- Is Valid - false 0
# |-- Is Valid - true 0
# ==========================
# Type: Value:  0

# %%
summarize_data(result_statistics['oggenc-nurs:depth-7200s'])
# Out:
# total queries:  44325
# failed queries:  0
# succeeded queries:  44325
# Type: Validity  0
# |-- Validity: -1  0
# |-- Validity: 0  0
# |-- Validity: 1  0
# ==========================
# Type: InitialValues  44325
# |-- Solvable: false  32323
# |-- Solvable: true  12002
# ==========================
# Type: Truth:  0
# |-- Is Valid - false 0
# |-- Is Valid - true 0
# ==========================
# Type: Value:  0

# %%
summarize_data(result_statistics['oggenc-random-path-7200s'])
# Out:
# total queries:  18908
# failed queries:  0
# succeeded queries:  18908
# Type: Validity  0
# |-- Validity: -1  0
# |-- Validity: 0  0
# |-- Validity: 1  0
# ==========================
# Type: InitialValues  18908
# |-- Solvable: false  12893
# |-- Solvable: true  6015
# ==========================
# Type: Truth:  0
# |-- Is Valid - false 0
# |-- Is Valid - true 0
# ==========================
# Type: Value:  0

# %%
summarize_data(result_statistics['sqlite3-dfs-7200s'])
# Out:
# total queries:  478
# failed queries:  0
# succeeded queries:  478
# Type: Validity  0
# |-- Validity: -1  0
# |-- Validity: 0  0
# |-- Validity: 1  0
# ==========================
# Type: InitialValues  478
# |-- Solvable: false  351
# |-- Solvable: true  127
# ==========================
# Type: Truth:  0
# |-- Is Valid - false 0
# |-- Is Valid - true 0
# ==========================
# Type: Value:  0

# %%
summarize_data(result_statistics['sqlite3-nurs:depth-7200s'])
# Out:
# total queries:  567
# failed queries:  0
# succeeded queries:  567
# Type: Validity  0
# |-- Validity: -1  0
# |-- Validity: 0  0
# |-- Validity: 1  0
# ==========================
# Type: InitialValues  567
# |-- Solvable: false  182
# |-- Solvable: true  385
# ==========================
# Type: Truth:  0
# |-- Is Valid - false 0
# |-- Is Valid - true 0
# ==========================
# Type: Value:  0

# %%
summarize_data(result_statistics['sqlite3-random-path-7200s'])
# Out:
# total queries:  273
# failed queries:  0
# succeeded queries:  273
# Type: Validity  0
# |-- Validity: -1  0
# |-- Validity: 0  0
# |-- Validity: 1  0
# ==========================
# Type: InitialValues  273
# |-- Solvable: false  55
# |-- Solvable: true  218
# ==========================
# Type: Truth:  0
# |-- Is Valid - false 0
# |-- Is Valid - true 0
# ==========================
# Type: Value:  0

# %%
summarize_data(result_statistics['tcpdump-dfs-7200s'])
# Out:
# total queries:  435
# failed queries:  0
# succeeded queries:  435
# Type: Validity  0
# |-- Validity: -1  0
# |-- Validity: 0  0
# |-- Validity: 1  0
# ==========================
# Type: InitialValues  435
# |-- Solvable: false  317
# |-- Solvable: true  118
# ==========================
# Type: Truth:  0
# |-- Is Valid - false 0
# |-- Is Valid - true 0
# ==========================
# Type: Value:  0

# %%
summarize_data(result_statistics['tcpdump-nurs:depth-7200s'])
# Out:
# total queries:  5463
# failed queries:  0
# succeeded queries:  5463
# Type: Validity  0
# |-- Validity: -1  0
# |-- Validity: 0  0
# |-- Validity: 1  0
# ==========================
# Type: InitialValues  5463
# |-- Solvable: false  2198
# |-- Solvable: true  3265
# ==========================
# Type: Truth:  0
# |-- Is Valid - false 0
# |-- Is Valid - true 0
# ==========================
# Type: Value:  0

# %%
summarize_data(result_statistics['tcpdump-random-path-7200s'])
# Out:
# total queries:  623
# failed queries:  0
# succeeded queries:  623
# Type: Validity  0
# |-- Validity: -1  0
# |-- Validity: 0  0
# |-- Validity: 1  0
# ==========================
# Type: InitialValues  623
# |-- Solvable: false  325
# |-- Solvable: true  298
# ==========================
# Type: Truth:  0
# |-- Is Valid - false 0
# |-- Is Valid - true 0
# ==========================
# Type: Value:  0
